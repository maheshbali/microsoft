# %% [markdown]
# <a href="https://colab.research.google.com/github/maheshbali/microsoft/blob/main/The_Cognitive_Skills_App_Emotion_Detection_prototype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
# !pip install deepface

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img1 = cv2.imread('/content/images.jpeg')
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img1)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.82it/s]

# %%
predictions
# Out:
# {'age': 21,
#  'dominant_emotion': 'sad',
#  'dominant_race': 'latino hispanic',
#  'emotion': {'angry': 6.691354912004168,
#   'disgust': 0.04651087788091617,
#   'fear': 33.5183700036031,
#   'happy': 4.357043913426632,
#   'neutral': 16.45293333845933,
#   'sad': 38.838159372696836,
#   'surprise': 0.09562922629552938},
#  'gender': 'Man',
#  'race': {'asian': 12.150801718235016,
#   'black': 3.4882746636867523,
#   'indian': 7.95355811715126,
#   'latino hispanic': 42.208507657051086,
#   'middle eastern': 11.18476316332817,
#   'white': 23.014095425605774},
#  'region': {'h': 143, 'w': 143, 'x': 32, 'y': 56}}

# %%
img2 = cv2.imread('/content/p066ss4c.jpeg')
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img2)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s]

# %%
predictions
# Out:
# {'age': 32,
#  'dominant_emotion': 'angry',
#  'dominant_race': 'indian',
#  'emotion': {'angry': 80.039381980896,
#   'disgust': 5.8234263633494265e-05,
#   'fear': 19.940590858459473,
#   'happy': 0.01260854332940653,
#   'neutral': 7.692070767006953e-05,
#   'sad': 0.007264782470883802,
#   'surprise': 2.428206471449812e-05},
#  'gender': 'Man',
#  'race': {'asian': 0.13954792770656513,
#   'black': 17.27063907805914,
#   'indian': 80.78853373459182,
#   'latino hispanic': 1.534442136254438,
#   'middle eastern': 0.12990511796802987,
#   'white': 0.13693734888359005},
#  'region': {'h': 255, 'w': 255, 'x': 351, 'y': 192}}

# %%
img3 = cv2.imread('/content/face-exaggeration-1553847.jpeg')
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img3)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.85it/s]

# %%
predictions
# Out:
# {'age': 34,
#  'dominant_emotion': 'neutral',
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.14220477314665914,
#   'disgust': 3.5134712561557535e-05,
#   'fear': 10.1607084274292,
#   'happy': 0.0855079386383295,
#   'neutral': 78.71503829956055,
#   'sad': 7.3074981570243835,
#   'surprise': 3.5890132188796997},
#  'gender': 'Man',
#  'race': {'asian': 7.791033387184143,
#   'black': 0.8010168559849262,
#   'indian': 3.1504277139902115,
#   'latino hispanic': 18.164967000484467,
#   'middle eastern': 19.01974081993103,
#   'white': 51.0728120803833},
#  'region': {'h': 160, 'w': 160, 'x': 81, 'y': 55}}

# %%
img4 = cv2.imread('/content/gettyimages-1092658864-612x612.jpeg')
plt.imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img4)
# Out:
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.09it/s]

# %%
predictions
# Out:
# {'age': 24,
#  'dominant_emotion': 'neutral',
#  'dominant_race': 'latino hispanic',
#  'emotion': {'angry': 0.9105745702981949,
#   'disgust': 2.1542698180887498e-10,
#   'fear': 0.07415552390739322,
#   'happy': 0.001876501482911408,
#   'neutral': 95.71066498756409,
#   'sad': 3.3027224242687225,
#   'surprise': 3.29599068038533e-06},
#  'gender': 'Man',
#  'race': {'asian': 8.078350871801376,
#   'black': 3.4760963171720505,
#   'indian': 7.031514495611191,
#   'latino hispanic': 39.55141007900238,
#   'middle eastern': 15.43237417936325,
#   'white': 26.430252194404602},
#  'region': {'h': 181, 'w': 181, 'x': 220, 'y': 83}}

# %%
img5 = cv2.imread('/content/hairstyles-for-oval-faces.jpeg')
plt.imshow(cv2.cvtColor(img5, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img5)
# Out:
# Action: race: 100%|██████████| 4/4 [00:05<00:00,  1.31s/it]

# %%
predictions
# Out:
# {'age': 30,
#  'dominant_emotion': 'sad',
#  'dominant_race': 'asian',
#  'emotion': {'angry': 0.9078834054907077,
#   'disgust': 1.5469069735175905e-07,
#   'fear': 0.5858279066290967,
#   'happy': 1.2914326733931254e-06,
#   'neutral': 16.910758088736763,
#   'sad': 81.59550647789163,
#   'surprise': 2.2389019878052192e-05},
#  'gender': 'Woman',
#  'race': {'asian': 38.734304904937744,
#   'black': 2.149161696434021,
#   'indian': 5.188585072755814,
#   'latino hispanic': 27.487286925315857,
#   'middle eastern': 7.20176100730896,
#   'white': 19.238901138305664},
#  'region': {'h': 396, 'w': 396, 'x': 431, 'y': 172}}

# %%
img6 = cv2.imread('/content/woman-with-toothache_c920e036-f45e-11e6-8b6e-25a65c287ec4.webp')
plt.imshow(cv2.cvtColor(img6, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img6)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.58it/s]

# %%
predictions
# Out:
# {'age': 26,
#  'dominant_emotion': 'fear',
#  'dominant_race': 'latino hispanic',
#  'emotion': {'angry': 0.24749303080224624,
#   'disgust': 0.002546476995328855,
#   'fear': 94.74864068643562,
#   'happy': 0.3882445397830558,
#   'neutral': 0.1928112006934046,
#   'sad': 3.0570980242373915,
#   'surprise': 1.3631616956696873},
#  'gender': 'Woman',
#  'race': {'asian': 12.08194864284686,
#   'black': 1.2824628335215351,
#   'indian': 7.379693977814554,
#   'latino hispanic': 56.74916248018518,
#   'middle eastern': 6.561852637639799,
#   'white': 15.94487970738886},
#  'region': {'h': 244, 'w': 244, 'x': 294, 'y': 101}}

# %%
img7 = cv2.imread('/content/Portrait_Female_Smile_Blond-1200x628-Facebook-1200x628.jpeg')
plt.imshow(cv2.cvtColor(img7, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img7)
# Out:
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.16it/s]

# %%
predictions
# Out:
# {'age': 33,
#  'dominant_emotion': 'happy',
#  'dominant_race': 'white',
#  'emotion': {'angry': 2.053938285517871e-06,
#   'disgust': 4.5965815947355376e-09,
#   'fear': 0.00636409746752635,
#   'happy': 99.73260167448501,
#   'neutral': 0.2476407851110953,
#   'sad': 0.0015620884325962332,
#   'surprise': 0.011827555181060859},
#  'gender': 'Woman',
#  'race': {'asian': 0.0027077331152140735,
#   'black': 0.0002825273104177362,
#   'indian': 0.08608165800715589,
#   'latino hispanic': 2.26540128703102,
#   'middle eastern': 16.356054978840948,
#   'white': 81.28946646577519},
#  'region': {'h': 442, 'w': 442, 'x': 436, 'y': 108}}
